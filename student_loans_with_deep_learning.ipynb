# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"].values


# Display a sample of y
y[:5]
# Out:
# array([0, 0, 0, 1, 0])

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns="credit_ranking").copy()

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score
# 0                  9.4
# 1                  9.8
# 2                  9.8
# 3                  9.8
# 4                  9.4

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
display(len(X_train))
display(len(X_test))
# Out:
# 1199
# 400

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scalar= StandardScaler()


# Fit the scaler to the features training dataset
X_scalar = scalar.fit(X_train)


# Fit the scaler to the features training dataset
X_train_scaled = X_scalar.transform(X_train)
X_test_scaled = X_scalar.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
len(X_train.columns)
# Out:
# 11

# %%
# Define the the number of inputs (features) to the model
num_input_features = len(X_train.columns)

# Review the number of features
num_input_features
# Out:
# 11

# %%
11//2
# Out:
# 5

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_layer_1 = num_input_features//2

# Define the number of hidden nodes for the second hidden layer
hidden_layer_2 = hidden_layer_1//2


# Define the number of neurons in the output layer
num_output_layer = 1

# %%
# Create the Sequential model instance
model = Sequential()

# Add the first hidden layer
model.add(Dense(input_dim=num_input_features, units=hidden_layer_1, activation="relu"))

# Add the second hidden layer
model.add(Dense(units=hidden_layer_2, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
model.add(Dense(units=num_output_layer, activation="sigmoid"))

# %%
# Display the Sequential model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 60
#
#  dense_1 (Dense)             (None, 2)                 12
#
#  dense_2 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 75 (300.00 Byte)
# Trainable params: 75 (300.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
model_fit = model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 2s 4ms/step - loss: 0.7240 - accuracy: 0.5596
# Epoch 2/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6847 - accuracy: 0.6055
# Epoch 3/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6657 - accuracy: 0.6239
# Epoch 4/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6526 - accuracy: 0.6364
# Epoch 5/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6415 - accuracy: 0.6472
# Epoch 6/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6322 - accuracy: 0.6589
# Epoch 7/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6242 - accuracy: 0.6639
# Epoch 8/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6177 - accuracy: 0.6672
# Epoch 9/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6119 - accuracy: 0.6764
# Epoch 10/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6068 - accuracy: 0.6822
# Epoch 11/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6017 - accuracy: 0.6881
# Epoch 12/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5969 - accuracy: 0.6956
# Epoch 13/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5929 - accuracy: 0.6989
# Epoch 14/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5892 - accuracy: 0.7048
# Epoch 15/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5854 - accuracy: 0.7056
# Epoch 16/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5824 - accuracy: 0.7098
# Epoch 17/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5789 - accuracy: 0.7106
# Epoch 18/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5765 - accuracy: 0.7148
# Epoch 19/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5737 - accuracy: 0.7131
# Epoch 20/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5713 - accuracy: 0.7156
# Epoch 21/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5688 - accuracy: 0.7189
# Epoch 22/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5667 - accuracy: 0.7173
# Epoch 23/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5646 - accuracy: 0.7173
# Epoch 24/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5625 - accuracy: 0.7214
# Epoch 25/50
# 38/38 [==============================] - 0s 9ms/step - loss: 0.5606 - accuracy: 0.7231
# Epoch 26/50
# 38/38 [==============================] - 0s 7ms/step - loss: 0.5590 - accuracy: 0.7264
# Epoch 27/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5574 - accuracy: 0.7339
# Epoch 28/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5558 - accuracy: 0.7339
# Epoch 29/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5540 - accuracy: 0.7356
# Epoch 30/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5523 - accuracy: 0.7398
# Epoch 31/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5508 - accuracy: 0.7373
# Epoch 32/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5493 - accuracy: 0.7389
# Epoch 33/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5479 - accuracy: 0.7398
# Epoch 34/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5462 - accuracy: 0.7415
# Epoch 35/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5452 - accuracy: 0.7415
# Epoch 36/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.5437 - accuracy: 0.7406
# Epoch 37/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5424 - accuracy: 0.7398
# Epoch 38/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5411 - accuracy: 0.7398
# Epoch 39/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5399 - accuracy: 0.7431
# Epoch 40/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5395 - accuracy: 0.7431
# Epoch 41/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5377 - accuracy: 0.7431
# Epoch 42/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5365 - accuracy: 0.7406
# Epoch 43/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5356 - accuracy: 0.7389
# Epoch 44/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5346 - accuracy: 0.7448
# Epoch 45/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5334 - accuracy: 0.7473
# Epoch 46/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5325 - accuracy: 0.7465
# Epoch 47/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5314 - accuracy: 0.7473
# Epoch 48/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5302 - accuracy: 0.7456
# Epoch 49/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5293 - accuracy: 0.7465
# Epoch 50/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5282 - accuracy: 0.7506

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test)

# Display the model loss and accuracy results
display(model_loss)
display(model_accuracy)
# Out:
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5396 - accuracy: 0.7350
# 0.5396059155464172
# 0.7350000143051147

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
filepath = Path("student_loans.keras")

# Export your model to a keras file
model.save(filepath)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
filepath = Path("student_loans.keras")


# Load the model to a new object
model_imported = tf.keras.models.load_model(filepath)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = model_imported.predict(X_test_scaled)


# Display a sample of the predictions
predictions[:5]
# Out:
# 13/13 [==============================] - 0s 3ms/step
# array([[0.6049893 ],
#        [0.32241422],
#        [0.79832333],
#        [0.6555514 ],
#        [0.9906751 ]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"]=round(predictions_df["predictions"], 0)
predictions_df
# Out:
#      predictions
# 0            1.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          1.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.77      0.73       188
#            1       0.77      0.71      0.74       212
#
#     accuracy                           0.73       400
#    macro avg       0.74      0.74      0.73       400
# weighted avg       0.74      0.73      0.74       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
